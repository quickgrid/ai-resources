# %% [markdown]
# <a href="https://colab.research.google.com/github/quickgrid/CodeLab/blob/master/colab/Youtube_Video_Download_and_Show.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Show mp4 video on Colab by downloading locally or to drive or as iframe

# %% [markdown]
# `**Best option is iframe for viewing or confirming youtube video. Use opencv for frame extraction from image. Not all method may work for large videos.**`

# %% [markdown]
# From,
#
# https://stackoverflow.com/questions/40713268/download-youtube-video-using-python-to-a-certain-directory/46981453#46981453
#
# https://python-pytube.readthedocs.io/en/latest/user/quickstart.html#downloading-a-video

# %%
# !pip install pytube3

# %%
youtube_url = input('Enter the youtube URL of the video you want to use : ')
# !rm -rf *.mp4
from pytube import YouTube
YouTube(youtube_url).streams.first().download('./')
# !mv *.mp4 video.mp4
# !ls -l
# Out:
# Enter the youtube URL of the video you want to use : https://www.youtube.com/watch?v=KMkuUaU8zks
# total 1724
# drwxr-xr-x 1 root root    4096 Aug 27 16:39 sample_data
# -rw-r--r-- 1 root root 1760190 Sep  9 16:52 video.mp4

# %%
youtube_url = input('Enter the youtube URL of the video you want to use : ')
from pytube import YouTube
yt = YouTube(youtube_url)
print(yt.streams)
# Out:
# Enter the youtube URL of the video you want to use : https://www.youtube.com/watch?v=KMkuUaU8zks
# ...

# %% [markdown]
# # Mount Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
## List files in certain folder
import os
print(os.listdir("/content/drive/My Drive/Delete"))
# Out:
# ['abc.mp4']

# %%
## Copy file to workspace
# !cp "/content/drive/My Drive/Delete/abc.mp4" .

# %% [markdown]
# # Play downloaded video. May not work for large files.

# %%
from IPython.display import HTML
from base64 import b64encode

# %%
mp4 = open('video.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# From, https://stackoverflow.com/questions/57377185/how-play-mp4-video-in-google-colab

# %% [markdown]
# # Upload to drive and show there

# %%
# !pip install -U kora
from kora.drive import upload_public
url = upload_public('video.mp4')
# then display it
from IPython.display import HTML
HTML(f"""<video src={url} width=500 controls/>""")
# Out:
# ...
# <video src=https://drive.google.com/uc?id=1yu6T_zm3kz-cA_tGLlUPMBjORvhY0Xtx width=500 controls/>

# %% [markdown]
# # Recommended for viewing

# %% [markdown]
# From, https://stackoverflow.com/questions/52050860/playing-videos-on-google-colab

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/KMkuUaU8zks" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/KMkuUaU8zks" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
